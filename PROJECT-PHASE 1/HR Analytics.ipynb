# %%
#Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
HR = pd.read_csv('/home/yashika/Downloads/ibm-hr-analytics-employee-attrition-performance/HR-Employee-Attrition.csv')
HR
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# Checking the shape of the dataset-
HR.shape
# Out:
# (1470, 35)

# %%
print("There are",HR.shape[0],'rows with',HR.shape[1],'columns.')
# Out:
# There are 1470 rows with 35 columns.

# %%
# checking the names of all the columns 
HR.columns.tolist()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
# Checking the info of the features in the dataset-
HR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# There are 1470 entries in our dataset with 35 attributes .
# All of the features in this dataset are in integer and object datatypes including our target variables 'Attrition'.
# The second column give us an idea about how big the dataset and how many non-null values are there for each field.

# %%
HR.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
plt.figure(figsize=[12,8])
sns.heatmap(HR.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are no null values present

# %%
# Checking duplicates in the dataset
HR.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values

# %%
#Description of the numerical features
HR.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
# Description of the categorcal features-
HR.describe(include=np.object)
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %% [markdown]
# there is no null data present in the dataset.
# The minimum age of employee in the company is 18 and max age is 60.
# The mean distance from home is coming out as 7 km that means on average employee has to travel around 14 km from home to office.
# 50% of Employees has worked atleast 2 companies previously.
# Mean is greater than median in few columns which indiacteds that there is skewness present in the data.
# By looking at Monthly Income and Monthly Rate values at 75% and max column ,we can say outliers exist.
# 'Education','EnvironmentSatisfaction','JobInvolvement', 'JobLevel', 'JobSatisfaction', RelationshipSatisfaction', 'PerformanceRating', 'WorkLifeBalance' are ordinal variable.

# %%
#Checking for unique elements
HR.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
# Checking values counts for each categorical columns

cat=HR.select_dtypes(include='object')
for col in cat:
    print('\n')
    print('********CATEGORICAL COLUMNS***************')
    print('---------------',col,'--------------------')
    print(HR[col].value_counts())


num=HR.select_dtypes(include='int64')
for col in num:
    print('\n')
    print('*********NUMERICAL FEATURES***************')
    print('---------------',col,'--------------------')
    print(HR[col].value_counts())
# Out:
# ********CATEGORICAL COLUMNS***************
# --------------- Attrition --------------------
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
#
#
# ********CATEGORICAL COLUMNS***************
# --------------- BusinessTravel --------------------
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
#
#
# ********CATEGORICAL COLUMNS***************
# --------------- Department --------------------
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
#
#
# ********CATEGORICAL COLUMNS***************
# --------------- EducationField --------------------
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
#
#
# ********CATEGORICAL COLUMNS***************
# --------------- Gender --------------------
# ...

# %% [markdown]
# In 'Attrition' We have two categories in the columns, i.e. 'Yes' and 'No'.Data is imbalanced.
# The employee count is found to be 1470 where all the employees should be over 18.
# There are three categories in the Bussiness travel column. i.e. 'Travel_Rarely','Travel_Frequently','Non-Travel'.
# There are three unique categories in the column 'Department'.
# There are 5 different job level and 9 different job roles in the dataset.

# %% [markdown]
# Data Visualisation

# %%
plt.figure(figsize=(25,25))
plot=1
for col in HR:
    if plot<18:
        plt.subplot(6,3,plot)
        sns.histplot(HR[col],bins = 6,kde = True)
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %%
plt.figure(figsize = [15,8])
sns.distplot(HR.TotalWorkingYears)
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Density'>

# %%
cat_cols=['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime']
sns.set_style('darkgrid')
for i in cat_cols:
    plt.figure(figsize=(12,2),facecolor='orange')
    plt.xticks(rotation=90)
    sns.countplot(x=i,data=HR,hue='Attrition',palette='rocket')
    plt.show(),

# %%
plt.figure(figsize=(25,25),facecolor='white')
plotnum=1

X = HR[['Education','Gender','EnvironmentSatisfaction','JobInvolvement','EducationField','BusinessTravel','Department','JobRole','PercentSalaryHike','NumCompaniesWorked','JobLevel','JobSatisfaction','MaritalStatus','OverTime','RelationshipSatisfaction','PerformanceRating','TrainingTimesLastYear','StockOptionLevel','WorkLifeBalance']]
Y = HR['Attrition']

for col in X:
    if plotnum<=24:
        plt.subplot(6,4,plotnum)
        sns.countplot(x = X[col],hue =Y,palette="viridis")
        plt.xlabel(col,fontsize=20)
        plt.ylabel('Count',fontsize=20)
        plt.xticks(rotation = 90)
    plotnum+=1
plt.tight_layout()

# %%
# Checking Attrition in different departments along with different Job role to check the Attrition rate -
pd.crosstab([HR.JobRole,HR.Department],[HR.Attrition], margins=True).style.background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_c9643_row0_col0, #T_c9643_row6_col2 {
#   background-color: #feead6;
#   color: #000000;
# }
# #T_c9643_row0_col1 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_c9643_row0_col2 {
#   background-color: #feebd8;
#   color: #000000;
# }
# #T_c9643_row1_col0 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_c9643_row1_col1, #T_c9643_row7_col2, #T_c9643_row10_col2 {
#   background-color: #ffefe0;
#   color: #000000;
# }
# #T_c9643_row1_col2, #T_c9643_row4_col2 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# #T_c9643_row2_col0 {
#   background-color: #fee2c6;
#   color: #000000;
# }
# #T_c9643_row2_col1 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_c9643_row2_col2 {
#   background-color: #fedebf;
#   color: #000000;
# }
# #T_c9643_row3_col0, #T_c9643_row3_col1, #T_c9643_row3_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_c9643_row4_col0, #T_c9643_row10_col0 {
# ...

# %%
# Checking the distribution of column Department Vs Education Field-
pd.crosstab([HR.Department],[HR.EducationField], margins=True).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_65236_row0_col0, #T_65236_row2_col2, #T_65236_row3_col0, #T_65236_row3_col1, #T_65236_row3_col2, #T_65236_row3_col3, #T_65236_row3_col4, #T_65236_row3_col5, #T_65236_row3_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_65236_row0_col1, #T_65236_row0_col2, #T_65236_row0_col3, #T_65236_row0_col4, #T_65236_row0_col5, #T_65236_row0_col6, #T_65236_row1_col0, #T_65236_row1_col2, #T_65236_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_65236_row1_col1 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_65236_row1_col3 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_65236_row1_col4 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_65236_row1_col5 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_65236_row1_col6 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_65236_row2_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_65236_row2_col3 {
# ...

# %%
#Checking skewness 
plt.figure(figsize=(15,25))
plot=1
for col in HR:
    if plot<=35:
        plt.subplot(7,5,plot)
        sns.distplot(HR[col])
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %%
plt.figure(figsize=(25,20),facecolor='white')
plot=1


X = HR[['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]
Y = HR['Attrition']

for col in X:
    if plot<=15:
        plt.subplot(5,5,plot)
        sns.barplot(x=Y,y=X[col],palette="flare")
        plt.xlabel('Attrition',fontsize=15)
        plt.ylabel(col,fontsize=15)
    plot+=1
plt.show()

# %%
plt.figure(figsize=(25,25),facecolor='lightyellow')
pt=1
for col in HR:
    if pt<=35:
        ax=plt.subplot(5,7,pt)
        sns.boxplot(HR[col])
        plt.xlabel(col,fontsize=15)
        pt+=1
plt.show()

# %%
sns.barplot(x='Gender',y='DistanceFromHome',hue='Attrition',data=HR,palette="mako")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='DistanceFromHome'>

# %%
col_data = HR[['Attrition','BusinessTravel','EducationField','Gender','JobRole','MaritalStatus','Over18','OverTime']]
for col in col_data:
    plt.figure(figsize = [15,8])
    HR[col].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
    plt.xticks(rotation = 90)

# %%
sns.lineplot(x='JobSatisfaction',y='YearsSinceLastPromotion',hue='Attrition',style='Attrition',marker='D',errorbar=None,data=HR,palette="Set2")
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='YearsSinceLastPromotion'>

# %%
sns.barplot(x='TotalWorkingYears',y='JobLevel',hue='Attrition',data=HR,palette="magma",orient='h')
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='JobLevel'>

# %%
sns.barplot(x='WorkLifeBalance',y='Age',hue='Attrition',data=HR,palette="Set2")
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='Age'>

# %%
sns.pointplot(x='EnvironmentSatisfaction',y='YearsAtCompany',hue='Attrition',data=HR,palette="rainbow",errwidth=0)
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='YearsAtCompany'>

# %%
sns.barplot(x='Department',y='MonthlyIncome',hue='Attrition',data=HR,palette='flare')
# Out:
# <AxesSubplot:xlabel='Department', ylabel='MonthlyIncome'>

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
onc = OrdinalEncoder()
le=LabelEncoder()

HR.select_dtypes(object).columns.tolist()
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
#Applying Label Encoder -

HR['Attrition'] = le.fit_transform(HR['Attrition'].values.reshape(-1,1))

# %%
#Applying Ordinal Encoder-

for i in HR.columns:
    if HR[i].dtypes =='object':
        HR[i] = onc.fit_transform(HR[i].values.reshape(-1,1)).astype('int64')

# %%
HR.head(5)
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
HR.dtypes
# Out:
# Age                         int64
# Attrition                   int64
# BusinessTravel              int64
# DailyRate                   int64
# Department                  int64
# DistanceFromHome            int64
# Education                   int64
# EducationField              int64
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                      int64
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int64
# JobSatisfaction             int64
# MaritalStatus               int64
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# Over18                      int64
# OverTime                    int64
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# ...

# %% [markdown]
# Encoded all the 'object' datatypes into 'int64'.

# %%
HR.drop(['StandardHours','EmployeeNumber','EmployeeCount','Over18'],axis=1,inplace=True)

# %%
#Plotting the correlation of columns
plt.figure(figsize=[25,10])
sns.heatmap(HR.corr(),annot = True, fmt = '0.2f',linewidths=3,linecolor='black')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (22,20))
HR.corr()['Attrition'].sort_values(ascending = False).drop(['Attrition']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Attrition',fontsize=15)
plt.title('CORRELATION OF TARGET VARIABLE -ATTRITION',fontsize =20)
plt.show()

# %% [markdown]
# The column 'OverTime' is having highest positive correlation with the target variable(24.6%).
# The column 'TotalWorkingYears' is having highest negative correlation with the target variable(-17.1%).
# The column 'BusinessTravel' is having the least positive correlation with the target variable(0.0074%), while the column 'HourlyRate' is having least negative correlation with the target variable(0.69%).
# The columns 'OverTime',MaritalStatus','DistanceFromHome','JobRole','Department','NumCompaniesWorked','Gender','EducationField','MonthlyRate','PerformanceRating','BusinessTravel' are positively correlated to the target variable.
# The columns 'HourlyRate','PercentSalaryHike','Education','YearsSinceLastPromotion','RelationshipSatisfaction','DailyRate','TrainingTimesLastYear','WorkLifeBalance','EnvironmentSatisfaction','JobSatisfaction','JobInvolvement','YearsAtCompany','StockOptionLevel','YearsWithCurrentManager','Age','MonthlyIncome','YearsinceCurrentRole','JobLevel','TotalWorkingYears' are negatively correlated to the target variable.

# %%
from scipy.stats import zscore

z =np.abs(zscore(HR))
print(z.shape)
# Out:
# (1470, 31)

# %%
df = HR.loc[(z<3).all(axis=1)]
print(df.shape)
# Out:
# (1387, 31)

# %%
print('Percentage loss of data using Z-score is :',(HR.shape[0]-df.shape[0])/HR.shape[0])
# Out:
# Percentage loss of data using Z-score is : 0.05646258503401361

# %%
#Splitting the dataset
x = HR.drop('Attrition',axis = 1)
y = HR['Attrition']

# %%
y.value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
# Using SMOTE to balance the categorical data-

from imblearn.over_sampling import SMOTE    # Importing library
sm= SMOTE()
x,y=sm.fit_resample(x,y)
y.value_counts()
# Out:
# 1    1233
# 0    1233
# Name: Attrition, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
x_scaled=pd.DataFrame(scaler.fit_transform(x),columns = x.columns)
x = x_scaled
x.T
# Out:
#                               0         1         2         3         4     \
# Age                       0.620976  1.514008  0.174460 -0.272056 -0.941830
# BusinessTravel            0.740519 -0.796619  0.740519 -0.796619  0.740519
# DailyRate                 0.864524 -1.306135  1.579285  1.629398 -0.483236
# Department                1.559820 -0.340633 -0.340633 -0.340633 -0.340633
# DistanceFromHome         -1.120802 -0.205777 -0.990084 -0.859367 -0.990084
# Education                -0.759978 -1.788012 -0.759978  1.296090 -1.788012
# EducationField           -0.915301 -0.915301  1.491879 -0.915301  0.689486
# EnvironmentSatisfaction  -0.456343  0.481442  1.419226  1.419226 -1.394127
# Gender                   -1.029636  0.971217  0.971217 -1.029636  0.971217
# HourlyRate                1.528088 -0.239994  1.420932 -0.507885 -1.365137
# JobInvolvement            0.643176 -0.707822 -0.707822  0.643176  0.643176
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def vifscore(x):
    vif = pd.DataFrame()
    vif['Column Name'] = x.columns
    vif['VIF Factor'] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif.sort_values('VIF Factor',ascending = False))

vifscore(x)
# Out:
#                  Column Name  VIF Factor
# 11                  JobLevel   11.156746
# 15             MonthlyIncome   10.560614
# 23         TotalWorkingYears    5.091131
# 26            YearsAtCompany    5.079667
# 27        YearsInCurrentRole    3.148780
# 29      YearsWithCurrManager    3.053544
# 0                        Age    2.126965
# 3                 Department    1.949767
# 19         PercentSalaryHike    1.880074
# 20         PerformanceRating    1.869260
# 28   YearsSinceLastPromotion    1.837817
# 12                   JobRole    1.818675
# 22          StockOptionLevel    1.615850
# 14             MaritalStatus    1.565933
# 17        NumCompaniesWorked    1.268117
# 10            JobInvolvement    1.107243
# 13           JobSatisfaction    1.088372
# 5                  Education    1.086006
# 25           WorkLifeBalance    1.082684
# 7    EnvironmentSatisfaction    1.069594
# 21  RelationshipSatisfaction    1.060292
# 16               MonthlyRate    1.056929
# ...

# %%
x1 = x.copy()
x1.drop(['MonthlyIncome'],axis = 1,inplace = True)
vifscore(x1)
# Out:
#                  Column Name  VIF Factor
# 25            YearsAtCompany    5.078093
# 22         TotalWorkingYears    4.977394
# 26        YearsInCurrentRole    3.147621
# 28      YearsWithCurrManager    3.044739
# 11                  JobLevel    2.878803
# 0                        Age    2.124553
# 3                 Department    1.933056
# 18         PercentSalaryHike    1.879504
# 19         PerformanceRating    1.869114
# 27   YearsSinceLastPromotion    1.826692
# 12                   JobRole    1.813607
# 21          StockOptionLevel    1.615581
# 14             MaritalStatus    1.565605
# 16        NumCompaniesWorked    1.267850
# 10            JobInvolvement    1.105033
# 5                  Education    1.085330
# 13           JobSatisfaction    1.083482
# 24           WorkLifeBalance    1.081592
# 7    EnvironmentSatisfaction    1.067731
# 20  RelationshipSatisfaction    1.059598
# 15               MonthlyRate    1.056474
# 23     TrainingTimesLastYear    1.054653
# ...

# %%
X = x1.copy()
Y = y.copy()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier , AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score   
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve

# %%
Model= [ DecisionTreeClassifier(),RandomForestClassifier(),SVC(),GradientBoostingClassifier(), KNeighborsClassifier(),LogisticRegression(), AdaBoostClassifier()]

# %%
def random_st(model):
    max_score = 0
    max_rs = 0
    print('\n',model)
    for i in range(1,50):
        x_train, x_test,y_train,y_test= train_test_split(x,y,test_size = 0.30, random_state = i)
        model.fit(x_train,y_train)
        pred_test = model.predict(x_test)
        score = accuracy_score(y_test,pred_test)
        if score > max_score:
            max_score = score
            max_rs = i
    print("At random state ", max_rs, 'the model is having accuracy score of ', max_score)
    return max_rs

# %%
def model_fit(model, rs):
    x_train, x_test,y_train,y_test= train_test_split(x,y,test_size = 0.30, random_state = rs)
    model.fit(x_train,y_train)
    pred_test = model.predict(x_test)
    print(f" Accuracy score is: {accuracy_score(y_test,pred_test)*100:.2f}")
    print ('\n','Confusion matrix:','\n',confusion_matrix(y_test,pred_test))
    print ('\n','Classification Report:','\n',classification_report(y_test,pred_test))

# %%
def cross_val(model,random_st):  
    cv_mean = 0
    cv_fold = 0
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.30, random_state = random_st)
    model.fit(x_train,y_train)
    pred_test = model.predict(x_test)
    for j in range(2,10):
        cv_score = cross_val_score(model,x,y, cv = j)
        a =cv_score.mean()
        if a>cv_mean:
            cv_mean = a
            cv_fold = j
    print("At cv fold",cv_fold," the cv score is ", cv_mean, "and the accuracy score  is ",accuracy_score(y_test,pred_test))
    print(f'\n Difference between accuracy score and cross val score {(accuracy_score(y_test,pred_test)-cv_mean)*100:.2f}')
    print("-"*50)

# %%
for m in Model:
    m_rs = random_st(m)
    model_fit(m,m_rs)
    cross_val(m,m_rs)
# Out:
#  DecisionTreeClassifier()
# At random state  14 the model is having accuracy score of  0.8527027027027027
#  Accuracy score is: 85.00
#
#  Confusion matrix:
#  [[306  55]
#  [ 56 323]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85       361
#            1       0.85      0.85      0.85       379
#
#     accuracy                           0.85       740
#    macro avg       0.85      0.85      0.85       740
# weighted avg       0.85      0.85      0.85       740
#
# At cv fold 9  the cv score is  0.8118410381184105 and the accuracy score  is  0.8432432432432433
#
#  Difference between accuracy score and cross val score 3.14
# --------------------------------------------------
#
#  RandomForestClassifier()
# At random state  37 the model is having accuracy score of  0.9297297297297298
#  Accuracy score is: 93.24
#
#  Confusion matrix:
#  [[351  17]
#  [ 33 339]]
#
#  Classification Report:
# ...

# %% [markdown]
# HyperParameter Tuning

# %%
params_rf = {'criterion':['gini','entropy'],
         'max_depth': [10,12,25],
         'min_samples_split' :[2,3,4],
         'min_samples_leaf' :[1,2,3]}

grid_cv = GridSearchCV(RandomForestClassifier(),param_grid = params_rf,n_jobs =-1)
grid_cv.fit(x,y)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 12, 25],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4]})

# %%
grid_cv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 25,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
grid_cv.best_score_
# Out:
# 0.9112555534568985

# %%
final_model = RandomForestClassifier(criterion = 'entropy', max_depth = 25, min_samples_leaf = 1, min_samples_split= 2)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=47)
final_model.fit(x_train, y_train)
pred_test = final_model.predict(x_test)
print(f" Accuracy score is: {accuracy_score(y_test,pred_test)*100:.2f}")
print ('\n','Confusion matrix:','\n',confusion_matrix(y_test,pred_test))
print ('\n','Classification Report:','\n',classification_report(y_test,pred_test))
# Out:
#  Accuracy score is: 90.69
#
#  Confusion matrix:
#  [[225  24]
#  [ 22 223]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91       249
#            1       0.90      0.91      0.91       245
#
#     accuracy                           0.91       494
#    macro avg       0.91      0.91      0.91       494
# weighted avg       0.91      0.91      0.91       494

# %%
import joblib
joblib.dump(final_model,"HR_analytics.pkl")
# Out:
# ['HR_analytics.pkl']

# %%
#Prediction using linear Regression model
Actual = np.array(y_test)
predicted = np.array(final_model.predict(x_test))
predicted_df = pd.DataFrame({'Original Value (W)':Actual,'Predicted Value (W)':predicted})
predicted_df
# Out:
#      Original Value (W)  Predicted Value (W)
# 0                     0                    0
# 1                     0                    0
# 2                     1                    1
# 3                     1                    1
# 4                     1                    1
# ..                  ...                  ...
# 489                   0                    0
# 490                   1                    1
# 491                   0                    1
# 492                   1                    1
# 493                   0                    0
#
# [494 rows x 2 columns]
