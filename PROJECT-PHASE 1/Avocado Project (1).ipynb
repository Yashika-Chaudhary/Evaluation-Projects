# %%
#Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# loading the dataset
avacado = pd.read_csv('https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/raw/master/avocado.csv.zip')
avacado
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
print("There are {:,} rows ".format(avacado.shape[0]) + "and {} columns in our data".format(avacado.shape[1]))
# Out:
# There are 18,249 rows and 14 columns in our data

# %%
#Display top 5 rows
avacado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
#Display bottom 5 rows
avacado.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
#Displaying list of all the columns
avacado.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Date',
#  'AveragePrice',
#  'Total Volume',
#  '4046',
#  '4225',
#  '4770',
#  'Total Bags',
#  'Small Bags',
#  'Large Bags',
#  'XLarge Bags',
#  'type',
#  'year',
#  'region']

# %%
#Display information about dataset
avacado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# Date has object datatype which needs to change,as date generally has datetime format.

# %%
# convering the date into datetime format.
avacado['Date']=pd.to_datetime(avacado['Date'])

# %%
avacado['Day'] = avacado['Date'].dt.day
avacado['Month'] = avacado['Date'].dt.month

# %%
avacado.dtypes
# Out:
# Unnamed: 0               int64
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# Day                      int64
# Month                    int64
# dtype: object

# %%
#Checking if any null value is present
avacado.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# Day             0
# Month           0
# dtype: int64

# %% [markdown]
# There is no null values in this dataset.

# %%
#Checking if any duplicate value is present
avacado.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate values in this dataset.

# %%
# Dropping the column "Unnamed:0"
avacado.drop('Unnamed: 0',axis =1 , inplace=True)

# %%
avacado.head(5)
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Day  Month
# 0  Albany   27     12
# 1  Albany   20     12
# 2  Albany   13     12
# 3  Albany    6     12
# ...

# %%
# Target variable
avacado['region'].value_counts()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# ...

# %%
avacado['region'].nunique()
# Out:
# 54

# %%
#Display statistical summary
avacado.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %% [markdown]
# All the columns has same count as 30 which means that there is no null values in the dataset.

# %% [markdown]
# Data Visualisation

# %%
plt.figure(figsize=(15,25))
plot=1
for col in avacado:
    if plot<=12:
        plt.subplot(4,3,plot)
        sns.histplot(avacado[col],bins = 6,kde = True)
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %%
plt.figure(figsize = [15,5])
sns.lineplot(x=avacado['region'],y=avacado['AveragePrice'],hue='type',data = avacado,palette = 'husl')
plt.xticks(rotation = 90)
plt.grid()
plt.show()

# %%
plt.figure(figsize = [15,5])
sns.barplot(x=avacado['region'],y=avacado['Total Volume'])
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = [8,8])
sns.barplot(x ='year',y ='Total Volume',hue='type',data = avacado)
plt.show()

# %%
countcol=avacado[['type','year','Month','region','Month']]
for i in countcol:
    plt.figure(figsize=(8,4))
    plt.xticks(rotation=90)
    sns.countplot(x=i,data=avacado,palette='Set2')

# %%
sns.barplot(x='Month',y='Total Volume',hue='type',data=avacado,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Total Volume'>

# %%
plt.figure(figsize=(12,6))
sns.pointplot(x='region',y='AveragePrice',hue='year',data=avacado,palette='husl')
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(avacado,x_vars=['4046', '4225', '4770'],y_vars='Total Volume',aspect=1,size=4,kind='reg',);

# %%
sns.pairplot(avacado,x_vars=['Small Bags', 'Large Bags', 'XLarge Bags'],y_vars='Total Volume',aspect=1,size=4,kind='reg')

# %%
#Encoding categorical column
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for i in avacado.columns:
    if avacado[i].dtypes == "object":
        avacado[i] = le.fit_transform(avacado[i].values.reshape(-1,1))

# %%
avacado.head(5)
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region  Day  \
# 0     8696.87     8603.62       93.25          0.0     0  2015       0   27
# 1     9505.56     9408.07       97.49          0.0     0  2015       0   20
# 2     8145.35     8042.21      103.14          0.0     0  2015       0   13
# 3     5811.16     5677.40      133.76          0.0     0  2015       0    6
# 4     6183.95     5986.26      197.69          0.0     0  2015       0   29
#
#    Month
# 0     12
# 1     12
# 2     12
# 3     12
# 4     11

# %%
#Checking the correlation matrix
avacado.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# type              0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# region           -0.011716      0.174176  0.192073  0.145726  0.095252
# ...

# %%
# Plotting the Correlation Matrix-
plt.figure(figsize=(15,10))
plt.title('Correlation Map',fontsize = 18)
sns.heatmap(avacado.corr(),annot=True,cmap='Greens')
# Out:
# <AxesSubplot:title={'center':'Correlation Map'}>

# %% [markdown]
# As we can from the heatmap above, all the Features are not correleted with the Average Price column, instead most of them are correlated with each other.

# %%
#1) Considering 'region' as target column
# CHECKING THE CORRELATION WITH THE TARGET VARIABLE 'Wins'.
plt.figure(figsize=(9,9))
avacado.corr()['region'].sort_values(ascending=False).drop(['region']).plot.bar(figsize=(10,8),color = 'g',grid=True,title='Correlation with Target',fontsize=15)
plt.xlabel('Input Features',fontsize = 14)
plt.ylabel('Average Price', fontsize =14)
plt.title('Correlation',fontsize=18)
plt.grid()
plt.show()

# %% [markdown]
# KEY OBSERVATIONS-
# Except 'year','Month','type' all other columns are having positive correlation with the column 'region'.
# The column 'Large Bags' is having highest positive correlation with the column 'region'. The column 'AveragePrice' is having highest negative correlation with the column 'region'.
# The column 'XLarge Bags' is having least positve correlation with the column 'region'. The column 'year' is having least negative correlation with the column 'region'

# %%
#2) Considering 'AveragePrice' as target column
# Checking the features correlation with the target variable

plt.figure(figsize = (15,7))
avacado.corr()['AveragePrice'].sort_values(ascending=False).drop(['AveragePrice']).plot(kind ='bar')
plt.xlabel('Input Features',fontsize = 14)
plt.ylabel('Average Price', fontsize =14)
plt.title('Correlation',fontsize=18)
plt.grid()
plt.show()

# %% [markdown]
# Here only few features are showing positive correlation withe the Target Attribute 'AveragePrice'.
# Mostly features are negatively correlated with our Target attribute 'AveragePrice'.
# The column 'Month' is having highest positive correlation with the column 'AveragePrice'. The column '4046' is having highest negative correlation with the column 'AveragePrice'.
# The column 'day' is having least positve correlation with the column 'AveragePrice'. The column 'XLarge Bags' is having least negative correlation with the column 'AveragePrice'.

# %%
#Checking skewness 
plt.figure(figsize=(15,25))
plot=1
for col in avacado:
    if plot<16:
        plt.subplot(5,3,plot)
        sns.distplot(avacado[col])
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %% [markdown]
# All the data is normally distributed

# %%
avacado.skew().sort_values(ascending = False)
# Out:
# XLarge Bags     13.139751
# 4770            10.159396
# Large Bags       9.796455
# Total Bags       9.756072
# Small Bags       9.540660
# Total Volume     9.007687
# 4225             8.942466
# 4046             8.648220
# AveragePrice     0.580303
# year             0.215339
# Month            0.106617
# Day              0.014310
# type             0.000329
# region           0.000030
# dtype: float64

# %%
#Plotting outliers
avacado_num=avacado.select_dtypes(include=['float64','int64'])
plt.figure(figsize=(15,20))
plot=1
for col in avacado_num:
    if plot<=15:
        plt.subplot(5,3,plot)
        sns.boxplot(avacado_num[col],color = 'r')
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %% [markdown]
# #ouliers are present in Errors,saves,ERA, shutouts,Runs

# %%
# Dropping the 'Date' column 
avacado.drop('Date',axis = 1, inplace = True)

# %%
avacado.head(5)
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Day  Month
# 0     8603.62       93.25          0.0     0  2015       0   27     12
# 1     9408.07       97.49          0.0     0  2015       0   20     12
# 2     8042.21      103.14          0.0     0  2015       0   13     12
# 3     5677.40      133.76          0.0     0  2015       0    6     12
# 4     5986.26      197.69          0.0     0  2015       0   29     11

# %%
avacado.skew().sort_values(ascending = False)
# Out:
# XLarge Bags     13.139751
# 4770            10.159396
# Large Bags       9.796455
# Total Bags       9.756072
# Small Bags       9.540660
# Total Volume     9.007687
# 4225             8.942466
# 4046             8.648220
# AveragePrice     0.580303
# year             0.215339
# Month            0.106617
# Day              0.014310
# type             0.000329
# region           0.000030
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
col = ['XLarge Bags','4770','Large Bags','Small Bags','Total Volume','4225','4046','Total Bags']
for i in col:    
    pt = PowerTransformer(method='yeo-johnson')
    avacado[col] = pt.fit_transform(avacado[col].values)

# %%
avacado.skew().sort_values(ascending = False)
# Out:
# XLarge Bags     0.676520
# AveragePrice    0.580303
# year            0.215339
# Month           0.106617
# Large Bags      0.046879
# Total Volume    0.039078
# Total Bags      0.031652
# Small Bags      0.030118
# 4770            0.029118
# 4225            0.019005
# Day             0.014310
# type            0.000329
# region          0.000030
# 4046           -0.005276
# dtype: float64

# %%
#Removing outliers using zscore
from scipy.stats import zscore
z =np.abs(zscore(avacado))
print(z.shape)
# Out:
# (18249, 14)

# %%
df = avacado.loc[(z<3).all(axis=1)]
df
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0              1.33     -0.095174 -0.660811  0.300314 -0.245616   -0.528418
# 1              1.35     -0.164120 -0.778289  0.224238 -0.199361   -0.490596
# 2              0.93      0.171014 -0.733671  0.574764 -0.005297   -0.556206
# 3              1.08     -0.004787 -0.636539  0.408855 -0.146600   -0.698336
# 4              1.28     -0.195891 -0.687320  0.217365 -0.136190   -0.672300
# ...             ...           ...       ...       ...       ...         ...
# 18244          1.63     -0.678701 -0.470589 -0.920056 -1.239275   -0.340148
# 18245          1.71     -0.770458 -0.622306 -0.669257 -1.239275   -0.501521
# 18246          1.87     -0.774359 -0.622255 -0.775088  0.402987   -0.495621
# 18247          1.93     -0.701897 -0.553093 -0.713901  0.402687   -0.429392
# 18248          1.62     -0.668055 -0.371550 -0.787603  0.124662   -0.390352
#
# ...

# %%
print(df.shape)
# Out:
# (18021, 14)

# %%
print('Percentage loss of data using Z-score is :',(avacado.shape[0]-df.shape[0])/avacado.shape[0])
# Out:
# Percentage loss of data using Z-score is : 0.012493835278645405

# %%
#Checking skewness
df.skew()
# Out:
# AveragePrice    0.396208
# Total Volume   -0.010887
# 4046           -0.053586
# 4225           -0.049962
# 4770            0.009831
# Total Bags      0.007668
# Small Bags     -0.047688
# Large Bags     -0.016544
# XLarge Bags     0.679794
# type            0.009212
# year            0.224877
# region          0.011945
# Day             0.014850
# Month           0.112280
# dtype: float64

# %%
# Split the features and the target variables into X and y respectively.
x=df.drop(columns=['region','Day','year','Month','type'],axis=1)
y=df['region']

# %%
x.shape
# Out:
# (18021, 9)

# %%
y.shape
# Out:
# (18021,)

# %%
x
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0              1.33     -0.095174 -0.660811  0.300314 -0.245616   -0.528418
# 1              1.35     -0.164120 -0.778289  0.224238 -0.199361   -0.490596
# 2              0.93      0.171014 -0.733671  0.574764 -0.005297   -0.556206
# 3              1.08     -0.004787 -0.636539  0.408855 -0.146600   -0.698336
# 4              1.28     -0.195891 -0.687320  0.217365 -0.136190   -0.672300
# ...             ...           ...       ...       ...       ...         ...
# 18244          1.63     -0.678701 -0.470589 -0.920056 -1.239275   -0.340148
# 18245          1.71     -0.770458 -0.622306 -0.669257 -1.239275   -0.501521
# 18246          1.87     -0.774359 -0.622255 -0.775088  0.402987   -0.495621
# 18247          1.93     -0.701897 -0.553093 -0.713901  0.402687   -0.429392
# 18248          1.62     -0.668055 -0.371550 -0.787603  0.124662   -0.390352
#
#        Small Bags  Large Bags  XLarge Bags
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 18244    53
# 18245    53
# 18246    53
# 18247    53
# 18248    53
# Name: region, Length: 18021, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
x_scaled=pd.DataFrame(scaler.fit_transform(x),columns = x.columns)
x = x_scaled
x
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0         -0.173210     -0.094289 -0.664180  0.310183 -0.246786   -0.544250
# 1         -0.121456     -0.164127 -0.782928  0.233162 -0.200250   -0.505354
# 2         -1.208303      0.175339 -0.737828  0.588042 -0.005009   -0.572827
# 3         -0.820143     -0.002734 -0.639645  0.420072 -0.147169   -0.718993
# 4         -0.302597     -0.196308 -0.690975  0.226203 -0.136695   -0.692218
# ...             ...           ...       ...       ...       ...         ...
# 18016      0.603109     -0.685358 -0.471900 -0.925347 -1.246475   -0.350634
# 18017      0.810127     -0.778302 -0.625258 -0.671432 -1.246475   -0.516589
# 18018      1.224164     -0.782253 -0.625207 -0.778578  0.405754   -0.510521
# 18019      1.379428     -0.708855 -0.555296 -0.716631  0.405452   -0.442412
# 18020      0.577232     -0.674575 -0.371789 -0.791248  0.125739   -0.402263
#
#        Small Bags  Large Bags  XLarge Bags
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def vifscore(x):
    vif = pd.DataFrame()
    vif['Column Name'] = x.columns
    vif['VIF Factor'] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif.sort_values('VIF Factor',ascending = False))

# %%
vifscore(x)
# Out:
#     Column Name  VIF Factor
# 1  Total Volume   52.845239
# 5    Total Bags   34.235652
# 6    Small Bags   15.843560
# 3          4225   11.998285
# 2          4046    6.876753
# 4          4770    3.654804
# 7    Large Bags    3.504679
# 8   XLarge Bags    1.826191
# 0  AveragePrice    1.772167

# %% [markdown]
# #Observation - Multicollinearity is present

# %%
x_scaled = x.drop(['Total Volume'], axis=1)
x= x_scaled

# %%
vifscore(x)
# Out:
#     Column Name  VIF Factor
# 4    Total Bags   24.317867
# 5    Small Bags   15.841063
# 2          4225    4.413643
# 1          4046    3.697118
# 3          4770    3.654779
# 6    Large Bags    3.399551
# 7   XLarge Bags    1.826081
# 0  AveragePrice    1.668019

# %%
x_scaled = x.drop(['Total Bags'], axis=1)
x= x_scaled

# %%
vifscore(x)
# Out:
#     Column Name  VIF Factor
# 2          4225    4.215191
# 1          4046    3.695704
# 4    Small Bags    3.659664
# 3          4770    3.645765
# 5    Large Bags    1.947910
# 6   XLarge Bags    1.825649
# 0  AveragePrice    1.575358

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score   
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve

# %%
def random_st_cls(model):
    max_score = 0
    max_rs = 0
    print('\n',model)
    for i in range(1,50):
        x_train, x_test,y_train,y_test= train_test_split(x,y,test_size = 0.20, random_state = i)
        model.fit(x_train,y_train)
        pred_test = model.predict(x_test)
        score = accuracy_score(y_test,pred_test)
        if score > max_score:
            max_score = score
            max_rs = i
    print("At random state ", max_rs, 'the model is having accuracy score of ', max_score)
    return max_rs

# %%
def model_fit_cls(model, rs):
    x_train, x_test,y_train,y_test= train_test_split(x,y,test_size = 0.20, random_state = rs)
    model.fit(x_train,y_train)
    pred_test = model.predict(x_test)
    cv_score = cross_val_score(model,x,y, cv = 8)
    cv_mean = cv_score.mean()
    print(f" Accuracy score is: {accuracy_score(y_test,pred_test)*100:.2f}")
    print ('\n','Confusion matrix:','\n',confusion_matrix(y_test,pred_test))
    print ('\n','Classification Report:','\n',classification_report(y_test,pred_test))
    print("The cv score is ", cv_mean, "and the accuracy score  is ",accuracy_score(y_test,pred_test))
    print(f'\n Difference between accuracy score and cross val score {(accuracy_score(y_test,pred_test)-cv_mean)*100:.2f}')
    print("-"*50)

# %%
def model_cls(m):
    m_rs = random_st_cls(m)
    model_fit_cls(m,m_rs)

# %%
model_cls(RandomForestClassifier())
# Out:
#  RandomForestClassifier()
# At random state  5 the model is having accuracy score of  0.9123439667128987
#  Accuracy score is: 91.73
#
#  Confusion matrix:
#  [[75  0  0 ...  0  0  0]
#  [ 0 56  0 ...  0  0  0]
#  [ 0  0 67 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 48  0  0]
#  [ 0  0  0 ...  0 55  0]
#  [ 0  0  0 ...  0  0 50]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91        82
#            1       0.86      0.92      0.89        61
#            2       0.94      1.00      0.97        67
#            3       0.89      0.92      0.91        63
#            4       0.92      0.93      0.93        61
#            5       0.90      0.80      0.85        66
#            6       0.97      0.97      0.97        63
#            7       0.96      0.88      0.92        78
#            8       0.96      0.98      0.97        65
#            9       0.95      0.89      0.92        65
# ...

# %% [markdown]
# Hyper Parameter Tuning

# %%
params = {'criterion':['gini','entropy'],
         'max_depth': [10,12,25],
         'min_samples_split' :[2,3,4],
         'min_samples_leaf' :[1,2,3]}

grid_rfc = GridSearchCV(RandomForestClassifier(),param_grid = params,n_jobs =-1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=5)

# %%
grid_rfc.fit(x_train,y_train)
grid_rfc.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 25,
#  'min_samples_leaf': 1,
#  'min_samples_split': 3}

# %%
grid_rfc.best_score_
# Out:
# 0.8861685724773325

# %%
final_model = RandomForestClassifier(criterion = 'entropy',max_depth = 25 ,min_samples_split = 3,min_samples_leaf = 1)
final_model.fit(x_train, y_train)
pred_test = final_model.predict(x_test)
print(f" Accuracy score is: {accuracy_score(y_test,pred_test)*100:.2f}")
print ('\n','Confusion matrix:','\n',confusion_matrix(y_test,pred_test))
print ('\n','Classification Report:','\n',classification_report(y_test,pred_test))
# Out:
#  Accuracy score is: 91.60
#
#  Confusion matrix:
#  [[74  0  0 ...  0  0  0]
#  [ 0 54  0 ...  0  0  0]
#  [ 0  0 66 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 48  0  0]
#  [ 0  0  0 ...  1 55  0]
#  [ 0  0  0 ...  0  0 51]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90        82
#            1       0.87      0.89      0.88        61
#            2       0.94      0.99      0.96        67
#            3       0.88      0.90      0.89        63
#            4       0.97      0.92      0.94        61
#            5       0.89      0.77      0.83        66
#            6       0.98      1.00      0.99        63
#            7       0.94      0.92      0.93        78
#            8       0.96      1.00      0.98        65
#            9       0.91      0.94      0.92        65
#           10       0.93      0.98      0.95        63
#           11       0.98      0.94      0.96        64
# ...

# %%
import pickle

filename = 'Avocado_region_classification.pkl'
pickle.dump(final_model,open(filename,'wb'))

# %% [markdown]
# # Regression Problem - To predict Average Price of Avacado

# %%
df.head(5)
# Out:
#    AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0          1.33     -0.095174 -0.660811  0.300314 -0.245616   -0.528418
# 1          1.35     -0.164120 -0.778289  0.224238 -0.199361   -0.490596
# 2          0.93      0.171014 -0.733671  0.574764 -0.005297   -0.556206
# 3          1.08     -0.004787 -0.636539  0.408855 -0.146600   -0.698336
# 4          1.28     -0.195891 -0.687320  0.217365 -0.136190   -0.672300
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Day  Month
# 0   -0.344161   -0.784732     -0.71742     0  2015       0   27     12
# 1   -0.310073   -0.775308     -0.71742     0  2015       0   20     12
# 2   -0.369745   -0.763311     -0.71742     0  2015       0   13     12
# 3   -0.499739   -0.707144     -0.71742     0  2015       0    6     12
# 4   -0.480179   -0.620201     -0.71742     0  2015       0   29     11

# %%
df.skew()
# Out:
# AveragePrice    0.396208
# Total Volume   -0.010887
# 4046           -0.053586
# 4225           -0.049962
# 4770            0.009831
# Total Bags      0.007668
# Small Bags     -0.047688
# Large Bags     -0.016544
# XLarge Bags     0.679794
# type            0.009212
# year            0.224877
# region          0.011945
# Day             0.014850
# Month           0.112280
# dtype: float64

# %%
X = df.drop(columns=['region','AveragePrice'],axis=1)
Y = df['AveragePrice']

print(X.shape)
print(Y.shape)
# Out:
# (18021, 12)
# (18021,)

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
X_scaled=pd.DataFrame(scaler.fit_transform(X),columns = X.columns)
X = X_scaled
X
# Out:
#        Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0         -0.094289 -0.664180  0.310183 -0.246786   -0.544250   -0.351877
# 1         -0.164127 -0.782928  0.233162 -0.200250   -0.505354   -0.316927
# 2          0.175339 -0.737828  0.588042 -0.005009   -0.572827   -0.378108
# 3         -0.002734 -0.639645  0.420072 -0.147169   -0.718993   -0.511391
# 4         -0.196308 -0.690975  0.226203 -0.136695   -0.692218   -0.491336
# ...             ...       ...       ...       ...         ...         ...
# 18016     -0.685358 -0.471900 -0.925347 -1.246475   -0.350634   -0.186451
# 18017     -0.778302 -0.625258 -0.671432 -1.246475   -0.516589   -0.336908
# 18018     -0.782253 -0.625207 -0.778578  0.405754   -0.510521   -0.319280
# 18019     -0.708855 -0.555296 -0.716631  0.405452   -0.442412   -0.258151
# 18020     -0.674575 -0.371789 -0.791248  0.125739   -0.402263   -0.220983
#
#        Large Bags  XLarge Bags      type      year       Day     Month
# ...

# %%
vifscore(X)
# Out:
#      Column Name  VIF Factor
# 0   Total Volume   53.992285
# 4     Total Bags   35.519106
# 5     Small Bags   15.356171
# 2           4225   11.283570
# 1           4046    6.990323
# 3           4770    4.191361
# 8           type    3.739154
# 6     Large Bags    3.526227
# 7    XLarge Bags    2.129969
# 9           year    1.386676
# 11         Month    1.056465
# 10           Day    1.000895

# %%
X_scaled = X.drop(['Total Volume','Total Bags'], axis=1)
X= X_scaled
vifscore(X)
# Out:
#    Column Name  VIF Factor
# 1         4225    4.362111
# 3   Small Bags    4.222612
# 2         4770    4.172546
# 0         4046    3.752945
# 6         type    3.452636
# 5  XLarge Bags    2.117669
# 4   Large Bags    1.996959
# 7         year    1.350466
# 9        Month    1.053422
# 8          Day    1.000698

# %%
# Importing required libraries

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso, RidgeCV, LassoCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
import pickle
from sklearn import metrics
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import cross_val_score

# %%
def random_st_reg(model):
    max_score = 0
    max_rs = 0
    print('\n',model)
    for i in range(1,50):
        x_train, x_test,y_train,y_test= train_test_split(X,Y,test_size = 0.20, random_state = i)
        model.fit(x_train,y_train)
        pred_test = model.predict(x_test)
        score = r2_score(y_test,pred_test)
        if score > max_score:
            max_score = score
            max_rs = i
    print("At random state ", max_rs, 'the model is having accuracy score of ', max_score)
    return max_rs

# %%
def model_fit_reg(model, rs):
    x_train, x_test,y_train,y_test= train_test_split(X,Y,test_size = 0.20, random_state = rs)
    model.fit(x_train,y_train)
    pred_test = model.predict(x_test)
    r2 = r2_score(y_test,pred_test)
    mse = mean_squared_error(y_test,pred_test)
    mae = mean_absolute_error(y_test,pred_test)
    cv_score = cross_val_score(model,X,Y, cv = 8)
    cv_mean = cv_score.mean()
    print("\n R2 score is ", r2)
    print("-"*50)
    print("Mean Sqaured Error is ",mse)
    print("-"*50)
    print("Mean Absolute Error is ",mae)
    print("-"*50)
    print("The cv score is ", cv_mean, "and the R2 score  is ",r2)
    print(f'\n Difference between accuracy score and cross val score {(r2-cv_mean)*100:.2f}')
    print("-"*50)

# %%
def model_reg(m):
    m_rs = random_st_reg(m)
    model_fit_reg(m,m_rs)

# %%
model_reg(RandomForestRegressor())
# Out:
#  RandomForestRegressor()
# At random state  45 the model is having accuracy score of  0.8793248733732504
#
#  R2 score is  0.8777523642376142
# --------------------------------------------------
# Mean Sqaured Error is  0.0187749283883495
# --------------------------------------------------
# Mean Absolute Error is  0.0964223023578363
# --------------------------------------------------
# The cv score is  0.32601916987687773 and the R2 score  is  0.8777523642376142
#
#  Difference between accuracy score and cross val score 55.17
# --------------------------------------------------

# %% [markdown]
# HyperParameter Tuning

# %%
params_rfr = {'criterion':["squared_error", "poisson"],
             'max_features':['auto','log2']}

grid_rfr = GridSearchCV(RandomForestRegressor(),params_rfr)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=45)

# %%
grid_rfr.fit(X_train,Y_train)
grid_rfr.best_params_
# Out:
# {'criterion': 'squared_error', 'max_features': 'auto'}

# %%
grid_rfr.best_score_
# Out:
# 0.857563080206867

# %%
final_model_reg = RandomForestRegressor(criterion ='squared_error',max_features = 'auto')
final_model_reg.fit(X_train,Y_train)
pred_test_reg = final_model_reg.predict(X_test)

print('R2 Score',r2_score(Y_test,pred_test_reg))
print('Mean Squared Error',mean_squared_error(Y_test,pred_test_reg))
print('Mean Absolute Error',mean_absolute_error(Y_test,pred_test_reg))
# Out:
# R2 Score 0.877666935081792
# Mean Squared Error 0.018788048693481264
# Mean Absolute Error 0.0962992510402219

# %%
filename = 'Avacado_price_reg.pkl'
pickle.dump(final_model_reg,open(filename,'wb'))
